# %%
import sys
# !{sys.executable} -m pip install cirq
# Out:
# ...
#   Using cached cirq-1.0.0-py3-none-any.whl (7.8 kB)
# ...
#   Using cached cirq_aqt-1.0.0-py3-none-any.whl (27 kB)
# ...
#   Using cached cirq_google-1.0.0-py3-none-any.whl (576 kB)
# ...
#   Using cached cirq_web-1.0.0-py3-none-any.whl (594 kB)
# ...
#   Using cached cirq_ionq-1.0.0-py3-none-any.whl (57 kB)
# ...
#   Using cached cirq_pasqal-1.0.0-py3-none-any.whl (31 kB)
# ...
#   Using cached cirq_rigetti-1.0.0-py3-none-any.whl (66 kB)
# ...
#   Using cached cirq_core-1.0.0-py3-none-any.whl (1.8 MB)
# ...
#      ---------------------------------------- 78.4/78.4 KB 4.3 MB/s eta 0:00:00
# ...
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# ...
#   Using cached duet-0.2.7-py3-none-any.whl (28 kB)
# ...
#   Using cached networkx-2.8.5-py3-none-any.whl (2.0 MB)
# ...
#   Using cached google_api_core-1.32.0-py2.py3-none-any.whl (93 kB)
# ...
#   Using cached proto_plus-1.20.6-py3-none-any.whl (46 kB)
# ...
#      -------------------------------------- 904.1/904.1 KB 5.2 MB/s eta 0:00:00
# ...
#   Using cached pyquil-3.1.0-py3-none-any.whl (220 kB)
# ...

# %%
# !{sys.executable} -m pip install cirq-core[contrib]
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\users\sriha\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...
#      ---------------------------------------- 84.1/84.1 KB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 2.4/2.4 MB 4.2 MB/s eta 0:00:00
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#      -------------------------------------- 353.6/353.6 KB 5.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 23.2/23.2 MB 5.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 329.0/329.0 KB 5.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.8/55.8 KB 3.0 MB/s eta 0:00:00
# Using legacy 'setup.py install' for pylatex, since package 'wheel' is not installed.
# ...
